# %%
#Simpson integral Method

import numpy as np
a = 1
b = 1.3
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.sqrt(x)

I_simp = (h/3) * (f[0] + 2*sum(f[:n-2:2]) + 4*sum(f[1:n-1:2]) + f[n-1])
err_simp = 0.321 - I_simp

print(I_simp)
print(err_simp)
# Out:
# 0.3414853676086068
# -0.020485367608606808
